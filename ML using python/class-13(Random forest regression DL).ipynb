# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\programming\\python\\jupyter\\ML\\files\\house_price_prediction.csv")

# %%
df
# Out:
#       bath  balcony   price  total_sqft_int  bhk  price_per_sqft
# 0        3      2.0  150.00          1672.0    3     8971.291866  \
# 1        3      3.0  149.00          1750.0    3     8514.285714
# 2        3      2.0  150.00          1750.0    3     8571.428571
# 3        2      2.0   40.00          1250.0    2     3200.000000
# 4        2      2.0   83.00          1200.0    2     6916.666667
# ...    ...      ...     ...             ...  ...             ...
# 7115     3      2.0  325.00          2900.0    3    11206.896550
# 7116     3      1.0   84.83          1780.0    3     4765.730337
# 7117     2      1.0   48.00           880.0    2     5454.545455
# 7118     2      1.0   55.00          1000.0    2     5500.000000
# 7119     2      1.0   78.00          1400.0    3     5571.428571
#
#       area_typeSuper built-up  Area  area_typeBuilt-up  Area
# 0                                 1                        0  \
# ...

# %%
x=df.drop("price",axis=1)

# %%
x
# Out:
#       bath  balcony  total_sqft_int  bhk  price_per_sqft
# 0        3      2.0          1672.0    3     8971.291866  \
# 1        3      3.0          1750.0    3     8514.285714
# 2        3      2.0          1750.0    3     8571.428571
# 3        2      2.0          1250.0    2     3200.000000
# 4        2      2.0          1200.0    2     6916.666667
# ...    ...      ...             ...  ...             ...
# 7115     3      2.0          2900.0    3    11206.896550
# 7116     3      1.0          1780.0    3     4765.730337
# 7117     2      1.0           880.0    2     5454.545455
# 7118     2      1.0          1000.0    2     5500.000000
# 7119     2      1.0          1400.0    3     5571.428571
#
#       area_typeSuper built-up  Area  area_typeBuilt-up  Area
# 0                                 1                        0  \
# 1                                 0                        1
# 2                                 1                        0
# ...

# %%
y=df["price"]

# %%
y
# Out:
# 0       150.00
# 1       149.00
# 2       150.00
# 3        40.00
# 4        83.00
#          ...
# 7115    325.00
# 7116     84.83
# 7117     48.00
# 7118     55.00
# 7119     78.00
# Name: price, Length: 7120, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=51)

# %%
x_train.shape
# Out:
# (5696, 107)

# %%
y_train.shape
# Out:
# (5696,)

# %%
x_test.shape
# Out:
# (1424, 107)

# %%
y_test.shape
# Out:
# (1424,)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr=RandomForestRegressor(n_estimators=100,criterion="squared_error")      #it uses 100 trees, it uses mean square error(mse)

# %%
rfr.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rfr.score(x_test,y_test)
# Out:
# 0.8974653156467798

# %%
rfr1=RandomForestRegressor(n_estimators=500,criterion="squared_error")      #it uses 100 trees, it uses mean square error(mse)

# %%
rfr1.fit(x_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=500)

# %%
rfr1.score(x_test,y_test)
# Out:
# 0.8946958178412857

# %%
x_test.iloc[-1,:]
# Out:
# bath                               2.00000
# balcony                            0.00000
# total_sqft_int                  1566.00000
# bhk                                2.00000
# price_per_sqft                 11494.25287
#                                   ...
# location_Hosur Road                0.00000
# location_Horamavu Banaswadi        0.00000
# location_Domlur                    0.00000
# location_Mahadevpura               0.00000
# location_Tumkur Road               0.00000
# Name: 43, Length: 107, dtype: float64

# %%
rfr.predict([x_test.iloc[-1,:]])
# Out:
# C:\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([175.17])

# %%
y_test.iloc[-1]
# Out:
# 180.0

# %%
y_predict=rfr.predict(x_test)

# %%
y_predict
# Out:
# array([ 79.7672 ,  39.9423 , 119.66   , ...,  33.14075,  63.388  ,
#        175.17   ])

# %%
y_forest
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 y_forest
#
# NameError: name 'y_forest' is not defined

# %%
from sklearn.metrics import mean_squared_error

# %%
mse=mean_squared_error(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 mse=Mean_squared_error(y_test,y_pred)
#
# NameError: name 'Mean_squared_error' is not defined

# %%
mse

# %%
rmse=np.sqrt(mse)

# %%
rmse
